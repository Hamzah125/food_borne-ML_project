# %%
import pandas  as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # load data

# %%
import seaborn as sns

# %%
df = pd.read_csv("../raw_data/spotifydataset.csv")

# %%
print(df.head())
# Out:
#    Unnamed: 0    artist_name genres  followers  artist_popularity  \
# 0           0  Ariana Grande    pop   98934105                 89
# 1           1  Ariana Grande    pop   98934105                 85
# 2           2  Ariana Grande    pop   98934105                 83
# 3           3  Ariana Grande    pop   98934105                 80
# 4           4  Ariana Grande    pop   98934105                 79
#
#                                           artist_url  \
# 0  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 1  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 2  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 3  https://open.spotify.com/artist/66CXWjxzNUsdJx...
# 4  https://open.spotify.com/artist/66CXWjxzNUsdJx...
#
#                                           track_name            album_name  \
# 0           we can't be friends (wait for your love)      eternal sunshine
# 1                                    the boy is mine      eternal sunshine
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1000 non-null   int64
#  1   artist_name        1000 non-null   object
#  2   genres             837 non-null    object
#  3   followers          1000 non-null   int64
#  4   artist_popularity  1000 non-null   int64
#  5   artist_url         1000 non-null   object
#  6   track_name         1000 non-null   object
#  7   album_name         1000 non-null   object
#  8   release_date       1000 non-null   object
#  9   duration_ms        1000 non-null   int64
#  10  explicit           1000 non-null   bool
#  11  track_popularity   1000 non-null   int64
#  12  danceability       1000 non-null   float64
#  13  energy             1000 non-null   float64
#  14  key                1000 non-null   int64
#  15  loudness           1000 non-null   float64
# ...

# %%
# Check how many missing (NaN) values are there in each column
print(df.isnull().sum())
# Out:
# Unnamed: 0             0
# artist_name            0
# genres               163
# followers              0
# artist_popularity      0
# artist_url             0
# track_name             0
# album_name             0
# release_date           0
# duration_ms            0
# explicit               0
# track_popularity       0
# danceability           0
# energy                 0
# key                    0
# loudness               0
# mode                   0
# speechiness            0
# acousticness           0
# instrumentalness       0
# liveness               0
# valence                0
# tempo                  0
# dtype: int64

# %%
# visualize the missing values
plt.figure(figsize=(12, 8))

# %%
plt.title('Missing Values in Dataset')
plt.show()

# %%
heatmap = sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title('Missing Values in Dataset')
plt.show()

# %%
df.isnull().sum() / len(df) * 100
# Out:
# Unnamed: 0            0.0
# artist_name           0.0
# genres               16.3
# followers             0.0
# artist_popularity     0.0
# artist_url            0.0
# track_name            0.0
# album_name            0.0
# release_date          0.0
# duration_ms           0.0
# explicit              0.0
# track_popularity      0.0
# danceability          0.0
# energy                0.0
# key                   0.0
# loudness              0.0
# mode                  0.0
# speechiness           0.0
# acousticness          0.0
# instrumentalness      0.0
# liveness              0.0
# valence               0.0
# tempo                 0.0
# dtype: float64

# %% [markdown]
# handling missing values

# %%
# Replace missing values in the 'genres' column with a placeholder
genres = "genres"
df[genres] = df[genres].fillna("Unknown")
print(df[genres].isnull().sum())
# Out:
# 0

# %%
# Ensure 'df' and 'genres' are defined before running this cell
if 'df' in globals() and 'genres' in globals():
	df.drop(columns=[genres], inplace=True)
else:
	print("Ensure that 'df' and 'genres' are defined before running this cell.")
# Out:
# Ensure that 'df' and 'genres' are defined before running this cell.

# %%
 df['genres'].fillna(df['genres'].mode()[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df['genres'].fillna(df['genres'].mode()[0])
#
# NameError: name 'df' is not defined

# %%
df['genres'].fillna(df['genres'].mode()[0], inplace=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_1804\931654054.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['genres'].fillna(df['genres'].mode()[0], inplace=True)

# %%
import pandas as pd

# %%
df = pd.read_csv("../raw_data/spotifydataset.csv")

# %%
# Step 1: Get mode value
most_common_genre = df['genres'].mode()[0]

# Step 2: Fill missing values properly
df['genres'] = df['genres'].fillna(most_common_genre)

# %%
df['genres'].isnull().sum()  # Check if there are still missing values in the 'genres' column
# Out:
# 0

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %%
df.to_csv('../processed/cleaned_data.csv', index=False)

# %%
import pandas as pd

# %%
df = pd.read_csv("../processed/cleaned_data.csv")

# %%
df.info()            # data types + missing values
df.isnull().sum()    # missing values summary
df.duplicated().sum() # check for duplicates
df.describe()        # for outlier detection
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 23 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         1000 non-null   int64
#  1   artist_name        1000 non-null   object
#  2   genres             1000 non-null   object
#  3   followers          1000 non-null   int64
#  4   artist_popularity  1000 non-null   int64
#  5   artist_url         1000 non-null   object
#  6   track_name         1000 non-null   object
#  7   album_name         1000 non-null   object
#  8   release_date       1000 non-null   object
#  9   duration_ms        1000 non-null   int64
#  10  explicit           1000 non-null   bool
#  11  track_popularity   1000 non-null   int64
#  12  danceability       1000 non-null   float64
#  13  energy             1000 non-null   float64
#  14  key                1000 non-null   int64
#  15  loudness           1000 non-null   float64
# ...

# %%
df['followers'].std()
# Out:
# 22938895.90549596

# %%
df.describe()
# Out:
#         Unnamed: 0     followers  artist_popularity    duration_ms  \
# count  1000.000000  1.000000e+03        1000.000000    1000.000000
# mean    499.500000  1.150655e+07          59.429000  212368.619000
# std     288.819436  2.293890e+07          23.884963   65706.472572
# min       0.000000  2.000000e+00           0.000000   51680.000000
# 25%     249.750000  1.038784e+06          57.000000  173083.000000
# 50%     499.500000  3.923159e+06          67.000000  204382.500000
# 75%     749.250000  1.142132e+07          74.000000  244192.750000
# max     999.000000  1.194287e+08          92.000000  707160.000000
#
#        track_popularity  danceability       energy          key     loudness  \
# count       1000.000000   1000.000000  1000.000000  1000.000000  1000.000000
# mean          59.429000      0.611430     0.660562     5.243000    -7.160373
# std           23.884963      0.167246     0.207568     3.613725     4.479642
# ...
